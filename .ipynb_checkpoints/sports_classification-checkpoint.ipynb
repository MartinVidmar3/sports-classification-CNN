# %%
# !pip install -q kagglehub
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

os.environ['KAGGLE_USERNAME'] = 'karlobasic'
os.environ['KAGGLE_KEY'] = 'KGAT_1bdeb74be3749cdcd52b1fc4724fb253'

# %%
import kagglehub

path = kagglehub.dataset_download("gpiosenka/sports-classification")
print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\ninad\.cache\kagglehub\datasets\gpiosenka\sports-classification\9.archive...
# 100%|███████████████████████████████████████████████████████████████████████████████| 424M/424M [01:48<00:00, 4.08MB/s]
# Extracting files...
# Path to dataset files: C:\Users\ninad\.cache\kagglehub\datasets\gpiosenka\sports-classification\versions\9

# %%
# !dir $path
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 948F-ACD8
#
#  Directory of C:\Users\ninad\.cache\kagglehub\datasets\gpiosenka\sports-classification\versions\9
#
# 12.01.2026.  20:51    <DIR>          .
# 12.01.2026.  20:51    <DIR>          ..
# 12.01.2026.  20:51        76.183.400 EfficientNetB0-100-(224 X 224)- 98.40.h5
# 12.01.2026.  20:51           686.576 sports.csv
# 12.01.2026.  20:51    <DIR>          test
# 12.01.2026.  20:51    <DIR>          train
# 12.01.2026.  20:51    <DIR>          valid
#                2 File(s)     76.869.976 bytes
#                5 Dir(s)  188.237.598.720 bytes free

# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader

import os
from tqdm import tqdm

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.optim as optim
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:264, in _load_dll_libraries()
#     260     err = ctypes.WinError(last_error)
#     261     err.strerror += (
#     262         f' Error loading "{dll}" or one of its dependencies.'
#     263     )
# --> 264     raise err
#     265 elif res is not None:
#     266     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "C:\Users\ninad\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
# !pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.9.1-cp311-cp311-win_amd64.whl (111.0 MB)
#      ------------------------------------ 111.0/111.0 MB 336.5 kB/s eta 0:00:00
# Collecting torchvision
#   Downloading torchvision-0.24.1-cp311-cp311-win_amd64.whl (4.0 MB)
#      ---------------------------------------- 4.0/4.0 MB 361.5 kB/s eta 0:00:00
# Collecting torchaudio
#   Downloading torchaudio-2.9.1-cp311-cp311-win_amd64.whl (664 kB)
#      ------------------------------------ 664.7/664.7 kB 470.5 kB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\ninad\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.14.0)
# Collecting typing-extensions>=4.10.0
#   Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#      -------------------------------------- 44.6/44.6 kB 545.6 kB/s eta 0:00:00
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ---------------------------------------- 6.3/6.3 MB 506.9 kB/s eta 0:00:00
# Collecting networkx>=2.5.1
#   Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 356.0 kB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\ninad\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.2)
# Collecting fsspec>=0.8.5
#   Downloading fsspec-2026.1.0-py3-none-any.whl (201 kB)
#      ------------------------------------ 201.8/201.8 kB 272.5 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\ninad\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\ninad\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (10.1.0)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ------------------------------------ 536.2/536.2 kB 431.5 kB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ninad\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (2.1.3)
# Installing collected packages: mpmath, typing-extensions, sympy, networkx, fsspec, torch, torchvision, torchaudio
# Successfully installed fsspec-2026.1.0 mpmath-1.3.0 networkx-3.6.1 sympy-1.14.0 torch-2.9.1 torchaudio-2.9.1 torchvision-0.24.1 typing-extensions-4.15.0
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       2 device
#
# NameError: name 'torch' is not defined

# %%
DATA_DIR = "/kaggle/input/sports-classification"

TRAIN_DIR = os.path.join(DATA_DIR, "train")
VALID_DIR = os.path.join(DATA_DIR, "valid")
TEST_DIR  = os.path.join(DATA_DIR, "test")

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
train_ds = datasets.ImageFolder(TRAIN_DIR, transform=transform)
valid_ds = datasets.ImageFolder(VALID_DIR, transform=transform)
test_ds  = datasets.ImageFolder(TEST_DIR,  transform=transform)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_ds, batch_size=32, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False)

num_classes = len(train_ds.classes)
num_classes
# Out:
# 100

# %%
model = models.resnet18(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

model.fc = nn.Linear(model.fc.in_features, num_classes)

model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=1e-4)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 189MB/s]

# %%
def train_epoch(model, loader):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    for x, y in tqdm(loader):
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, preds = torch.max(out, 1)
        correct += (preds == y).sum().item()
        total += y.size(0)

    return running_loss / len(loader), correct / total

# %%
def eval_epoch(model, loader):
    model.eval()
    running_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            out = model(x)
            loss = criterion(out, y)

            running_loss += loss.item()
            _, preds = torch.max(out, 1)
            correct += (preds == y).sum().item()
            total += y.size(0)

    return running_loss / len(loader), correct / total

# %%
EPOCHS = 30
patience = 3
best_val_loss = float('inf')
patience_counter = 0

best_model_state = None

for epoch in range(EPOCHS):
    train_loss, train_acc = train_epoch(model, train_loader)
    val_loss, val_acc = eval_epoch(model, valid_loader)

    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f" Train loss: {train_loss:.4f}, acc: {train_acc:.4f}")
    print(f" Validation loss: {val_loss:.4f}, acc: {val_acc:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = model.state_dict()
        print("Validation loss improved")
    else:
        patience_counter += 1
        print(f"No improvement ({patience_counter}/{patience})")

    print("-" * 40)

    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

if best_model_state is not None:
    model.load_state_dict(best_model_state)
# Out:
# 100%|██████████| 422/422 [01:46<00:00,  3.95it/s]
# Epoch 1/30
#  Train loss: 4.1680, acc: 0.1253
#  Validation loss: 3.6031, acc: 0.3060
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:44<00:00,  9.47it/s]
# Epoch 2/30
#  Train loss: 3.2179, acc: 0.4358
#  Validation loss: 2.7549, acc: 0.5720
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:48<00:00,  8.70it/s]
# Epoch 3/30
#  Train loss: 2.5489, acc: 0.6115
#  Validation loss: 2.1719, acc: 0.6680
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:48<00:00,  8.63it/s]
# Epoch 4/30
#  Train loss: 2.0821, acc: 0.6983
#  Validation loss: 1.7674, acc: 0.7280
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:44<00:00,  9.57it/s]
# Epoch 5/30
#  Train loss: 1.7486, acc: 0.7463
#  Validation loss: 1.4712, acc: 0.7700
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:45<00:00,  9.37it/s]
# Epoch 6/30
#  Train loss: 1.5107, acc: 0.7776
#  Validation loss: 1.2731, acc: 0.8040
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:47<00:00,  8.95it/s]
# Epoch 7/30
#  Train loss: 1.3327, acc: 0.7951
#  Validation loss: 1.1308, acc: 0.8180
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:48<00:00,  8.66it/s]
# Epoch 8/30
#  Train loss: 1.1945, acc: 0.8141
#  Validation loss: 1.0190, acc: 0.8200
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:47<00:00,  8.90it/s]
# Epoch 9/30
#  Train loss: 1.0831, acc: 0.8274
#  Validation loss: 0.9381, acc: 0.8260
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:46<00:00,  9.14it/s]
# Epoch 10/30
#  Train loss: 0.9922, acc: 0.8373
#  Validation loss: 0.8534, acc: 0.8440
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
cm = confusion_matrix(all_labels, all_preds)
class_names = train_ds.classes

for i, class_name in enumerate(class_names):
    total = cm[i].sum()
    correct = cm[i, i]

    print(f"\nClass: {class_name}")
    print(f"  Total samples : {total}")
    print(f"  Correct hits  : {correct}")

    errors = cm[i].copy()
    errors[i] = 0

    if errors.sum() == 0:
        print("  Incorrect: 0")
        continue

    print("  Misclassified as:")
    for j, count in enumerate(errors):
        if count > 0:
            print(f"    → {class_names[j]} : {count}")
# Out:
# Class: air hockey
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ampute football
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: archery
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → pole vault : 1
#     → tennis : 1
#
# Class: arm wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: axe throwing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: balance beam
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: barell racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: baseball
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → cricket : 1
#     → football : 1
#
# Class: basketball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: baton twirling
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → javelin : 1
#
# Class: bike polo
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → bmx : 2
#
# Class: billiards
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bmx
#   Total samples : 5
#   Correct hits  : 2
#   Misclassified as:
#     → sky surfing : 1
#     → wheelchair racing : 2
#
# Class: bobsled
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bowling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: boxing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bull riding
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bungee jumping
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: canoe slamon
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: cheerleading
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → basketball : 1
#     → skydiving : 1
#
# Class: chuckwagon racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: cricket
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: croquet
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: curling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: disc golf
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: fencing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: field hockey
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: figure skating men
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: figure skating pairs
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: figure skating women
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: fly fishing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: football
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: formula 1 racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: frisbee
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → log rolling : 1
#
# Class: gaga
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → air hockey : 1
#
# Class: giant slalom
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: golf
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hammer throw
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hang gliding
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: harness racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: high jump
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hockey
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horse jumping
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horse racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horseshoe pitching
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → frisbee : 1
#
# Class: hurdles
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hydroplane racing
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → bobsled : 1
#     → sailboat racing : 1
#
# Class: ice climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ice yachting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: jai alai
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: javelin
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: jousting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: judo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: lacrosse
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → football : 2
#
# Class: log rolling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: luge
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: motorcycle racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: mushing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → snowmobile racing : 1
#
# Class: nascar racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: olympic wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: parallel bar
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pole climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pole dancing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pole vault
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: polo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pommel horse
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rings
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rock climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: roller derby
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rollerblade racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rowing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rugby
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sailboat racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: shot put
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → javelin : 1
#
# Class: shuffleboard
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sidecar racing
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → motorcycle racing : 2
#
# Class: ski jumping
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sky surfing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → snow boarding : 1
#
# Class: skydiving
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: snow boarding
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → ski jumping : 1
#
# Class: snowmobile racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: speed skating
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: steer wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sumo wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: surfing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: swimming
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → water polo : 1
#
# Class: table tennis
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: tennis
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → hurdles : 1
#     → weightlifting : 1
#
# Class: track bicycle
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: trapeze
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → balance beam : 1
#     → pole climbing : 1
#
# Class: tug of war
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ultimate
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → lacrosse : 1
#     → tug of war : 1
#
# Class: uneven bars
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: volleyball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: water cycling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: water polo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: weightlifting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wheelchair basketball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wheelchair racing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → bmx : 1
#
# Class: wingsuit flying
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0

# %%
misclassified = defaultdict(list)

for idx, (true_label, pred_label) in enumerate(zip(all_labels, all_preds)):
    if true_label != pred_label:
        img_path, _ = test_ds.samples[idx]

        true_name = test_ds.classes[true_label]
        pred_name = test_ds.classes[pred_label]

        misclassified[true_name].append({
            "image": img_path,
            "predicted": pred_name
        })

for true_class, items in misclassified.items():
    print(f"\nClass: {true_class}")
    print(f"  Misclassified samples: {len(items)}")

    for item in items:
        print(f"    Image: {item['image']}")
        print(f"      → Predicted as: {item['predicted']}")
# Out:
# Class: archery
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/archery/2.jpg
#       → Predicted as: pole vault
#     Image: /kaggle/input/sports-classification/test/archery/3.jpg
#       → Predicted as: tennis
#
# Class: baseball
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/baseball/1.jpg
#       → Predicted as: cricket
#     Image: /kaggle/input/sports-classification/test/baseball/3.jpg
#       → Predicted as: football
#
# Class: baton twirling
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/baton twirling/5.jpg
#       → Predicted as: javelin
#
# Class: bike polo
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/bike polo/1.jpg
#       → Predicted as: bmx
#     Image: /kaggle/input/sports-classification/test/bike polo/3.jpg
#       → Predicted as: bmx
#
# Class: bmx
#   Misclassified samples: 3
#     Image: /kaggle/input/sports-classification/test/bmx/1.jpg
#       → Predicted as: wheelchair racing
#     Image: /kaggle/input/sports-classification/test/bmx/2.jpg
#       → Predicted as: sky surfing
#     Image: /kaggle/input/sports-classification/test/bmx/5.jpg
#       → Predicted as: wheelchair racing
#
# Class: cheerleading
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/cheerleading/3.jpg
#       → Predicted as: skydiving
#     Image: /kaggle/input/sports-classification/test/cheerleading/5.jpg
#       → Predicted as: basketball
#
# Class: frisbee
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/frisbee/4.jpg
#       → Predicted as: log rolling
#
# Class: gaga
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/gaga/5.jpg
#       → Predicted as: air hockey
#
# Class: horseshoe pitching
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/horseshoe pitching/2.jpg
#       → Predicted as: frisbee
#
# Class: hydroplane racing
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/hydroplane racing/2.jpg
#       → Predicted as: sailboat racing
#     Image: /kaggle/input/sports-classification/test/hydroplane racing/5.jpg
#       → Predicted as: bobsled
#
# Class: lacrosse
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/lacrosse/2.jpg
#       → Predicted as: football
#     Image: /kaggle/input/sports-classification/test/lacrosse/4.jpg
#       → Predicted as: football
#
# Class: mushing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/mushing/2.jpg
#       → Predicted as: snowmobile racing
#
# Class: shot put
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/shot put/2.jpg
#       → Predicted as: javelin
#
# Class: sidecar racing
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/sidecar racing/3.jpg
#       → Predicted as: motorcycle racing
#     Image: /kaggle/input/sports-classification/test/sidecar racing/5.jpg
#       → Predicted as: motorcycle racing
#
# Class: sky surfing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/sky surfing/1.jpg
#       → Predicted as: snow boarding
#
# Class: snow boarding
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/snow boarding/5.jpg
#       → Predicted as: ski jumping
#
# Class: swimming
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/swimming/2.jpg
#       → Predicted as: water polo
#
# Class: tennis
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/tennis/4.jpg
#       → Predicted as: weightlifting
#     Image: /kaggle/input/sports-classification/test/tennis/5.jpg
#       → Predicted as: hurdles
#
# Class: trapeze
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/trapeze/2.jpg
#       → Predicted as: balance beam
#     Image: /kaggle/input/sports-classification/test/trapeze/3.jpg
#       → Predicted as: pole climbing
#
# Class: ultimate
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/ultimate/2.jpg
#       → Predicted as: tug of war
#     Image: /kaggle/input/sports-classification/test/ultimate/5.jpg
#       → Predicted as: lacrosse
#
# Class: wheelchair racing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/wheelchair racing/3.jpg
#       → Predicted as: bmx

# %%
from google.colab import drive
drive.mount('/content/drive')

torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'epoch': epoch
}, "/content/drive/MyDrive/resnet.pth")
# Out:
# Mounted at /content/drive

# %%
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(
        brightness=0.2, contrast=0.2, saturation=0.2
    ),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
eval_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
train_ds = datasets.ImageFolder(TRAIN_DIR, transform=train_transform)
valid_ds = datasets.ImageFolder(VALID_DIR, transform=eval_transform)
test_ds  = datasets.ImageFolder(TEST_DIR,  transform=eval_transform)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_ds, batch_size=32, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False)

num_classes = len(train_ds.classes)
num_classes
# Out:
# 100

# %%
model = models.resnet18(pretrained=True)

for name, param in model.named_parameters():
    if "layer4" in name:
        param.requires_grad = True

model.fc = nn.Linear(model.fc.in_features, num_classes)

model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-5
)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:55<00:00,  3.67it/s]
# Epoch 21/30
#  Train loss: 0.8057, acc: 0.8252
#  Validation loss: 0.3988, acc: 0.9140
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:53<00:00,  3.72it/s]
# Epoch 22/30
#  Train loss: 0.7693, acc: 0.8314
#  Validation loss: 0.3750, acc: 0.9120
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:54<00:00,  3.67it/s]
# Epoch 23/30
#  Train loss: 0.7619, acc: 0.8337
#  Validation loss: 0.3603, acc: 0.9160
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:56<00:00,  3.63it/s]
# Epoch 24/30
#  Train loss: 0.7350, acc: 0.8386
#  Validation loss: 0.3534, acc: 0.9220
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:51<00:00,  3.77it/s]
# Epoch 25/30
#  Train loss: 0.6966, acc: 0.8502
#  Validation loss: 0.3642, acc: 0.9220
# No improvement (1/3)
# ----------------------------------------
# 100%|██████████| 422/422 [01:54<00:00,  3.68it/s]
# Epoch 26/30
#  Train loss: 0.6780, acc: 0.8487
#  Validation loss: 0.3417, acc: 0.9280
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:57<00:00,  3.58it/s]
# Epoch 27/30
#  Train loss: 0.6729, acc: 0.8497
#  Validation loss: 0.3179, acc: 0.9300
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:56<00:00,  3.62it/s]
# Epoch 28/30
#  Train loss: 0.6546, acc: 0.8560
#  Validation loss: 0.3151, acc: 0.9280
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:54<00:00,  3.69it/s]
# Epoch 29/30
#  Train loss: 0.6294, acc: 0.8592
#  Validation loss: 0.3063, acc: 0.9320
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:53<00:00,  3.73it/s]
# Epoch 30/30
#  Train loss: 0.6170, acc: 0.8629
#  Validation loss: 0.2959, acc: 0.9360
# Validation loss improved
# ----------------------------------------

# %%
test_loss, test_acc = eval_epoch(model, test_loader)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Test accuracy: 0.9360

# %%
all_preds = []
all_labels = []

model.eval()
with torch.no_grad():
    for x, y in test_loader:
        x, y = x.to(device), y.to(device)
        out = model(x)
        _, preds = torch.max(out, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y.cpu().numpy())

# %%
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(12,10))
sns.heatmap(
    cm,
    xticklabels=train_ds.classes,
    yticklabels=train_ds.classes,
    cmap="Blues",
    fmt="d"
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
cm = confusion_matrix(all_labels, all_preds)
class_names = train_ds.classes

for i, class_name in enumerate(class_names):
    total = cm[i].sum()
    correct = cm[i, i]

    print(f"\nClass: {class_name}")
    print(f"  Total samples : {total}")
    print(f"  Correct hits  : {correct}")

    errors = cm[i].copy()
    errors[i] = 0

    if errors.sum() == 0:
        print("  Incorrect: 0")
        continue

    print("  Misclassified as:")
    for j, count in enumerate(errors):
        if count > 0:
            print(f"    → {class_names[j]} : {count}")
# Out:
# Class: air hockey
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ampute football
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: archery
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → pole vault : 1
#
# Class: arm wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: axe throwing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: balance beam
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: barell racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: baseball
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → cricket : 2
#
# Class: basketball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: baton twirling
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → javelin : 1
#     → tennis : 1
#
# Class: bike polo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: billiards
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bmx
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → bike polo : 1
#
# Class: bobsled
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → luge : 1
#
# Class: bowling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: boxing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bull riding
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bungee jumping
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → trapeze : 1
#
# Class: canoe slamon
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → surfing : 1
#
# Class: cheerleading
#   Total samples : 5
#   Correct hits  : 2
#   Misclassified as:
#     → basketball : 1
#     → football : 1
#     → lacrosse : 1
#
# Class: chuckwagon racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: cricket
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: croquet
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: curling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: disc golf
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: fencing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: field hockey
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: figure skating men
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: figure skating pairs
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → figure skating women : 1
#
# Class: figure skating women
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: fly fishing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: football
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: formula 1 racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: frisbee
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → figure skating women : 1
#
# Class: gaga
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → jai alai : 1
#
# Class: giant slalom
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: golf
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hammer throw
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hang gliding
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: harness racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: high jump
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hockey
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horse jumping
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horse racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horseshoe pitching
#   Total samples : 5
#   Correct hits  : 2
#   Misclassified as:
#     → frisbee : 3
#
# Class: hurdles
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hydroplane racing
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → bobsled : 1
#     → sailboat racing : 1
#
# Class: ice climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ice yachting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: jai alai
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: javelin
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: jousting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: judo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: lacrosse
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: log rolling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: luge
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: motorcycle racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: mushing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: nascar racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: olympic wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: parallel bar
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pole climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pole dancing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pole vault
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → uneven bars : 1
#
# Class: polo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pommel horse
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rings
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rock climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: roller derby
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → football : 1
#
# Class: rollerblade racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rowing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rugby
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sailboat racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: shot put
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → javelin : 1
#
# Class: shuffleboard
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sidecar racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ski jumping
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sky surfing
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → skydiving : 1
#     → snow boarding : 1
#
# Class: skydiving
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: snow boarding
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: snowmobile racing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → formula 1 racing : 1
#
# Class: speed skating
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: steer wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sumo wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: surfing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: swimming
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → water polo : 1
#
# Class: table tennis
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: tennis
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: track bicycle
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: trapeze
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → balance beam : 1
#
# Class: tug of war
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ultimate
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → tug of war : 2
#
# Class: uneven bars
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: volleyball
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → javelin : 1
#     → tennis : 1
#
# Class: water cycling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: water polo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: weightlifting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wheelchair basketball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wheelchair racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wingsuit flying
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0

# %%
misclassified = defaultdict(list)

for idx, (true_label, pred_label) in enumerate(zip(all_labels, all_preds)):
    if true_label != pred_label:
        img_path, _ = test_ds.samples[idx]

        true_name = test_ds.classes[true_label]
        pred_name = test_ds.classes[pred_label]

        misclassified[true_name].append({
            "image": img_path,
            "predicted": pred_name
        })

for true_class, items in misclassified.items():
    print(f"\nClass: {true_class}")
    print(f"  Misclassified samples: {len(items)}")

    for item in items:
        print(f"    Image: {item['image']}")
        print(f"      → Predicted as: {item['predicted']}")
# Out:
# Class: archery
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/archery/3.jpg
#       → Predicted as: pole vault
#
# Class: baseball
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/baseball/1.jpg
#       → Predicted as: cricket
#     Image: /kaggle/input/sports-classification/test/baseball/2.jpg
#       → Predicted as: cricket
#
# Class: baton twirling
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/baton twirling/1.jpg
#       → Predicted as: tennis
#     Image: /kaggle/input/sports-classification/test/baton twirling/5.jpg
#       → Predicted as: javelin
#
# Class: bmx
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/bmx/1.jpg
#       → Predicted as: bike polo
#
# Class: bobsled
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/bobsled/3.jpg
#       → Predicted as: luge
#
# Class: bungee jumping
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/bungee jumping/4.jpg
#       → Predicted as: trapeze
#
# Class: canoe slamon
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/canoe slamon/3.jpg
#       → Predicted as: surfing
#
# Class: cheerleading
#   Misclassified samples: 3
#     Image: /kaggle/input/sports-classification/test/cheerleading/2.jpg
#       → Predicted as: football
#     Image: /kaggle/input/sports-classification/test/cheerleading/3.jpg
#       → Predicted as: lacrosse
#     Image: /kaggle/input/sports-classification/test/cheerleading/5.jpg
#       → Predicted as: basketball
#
# Class: figure skating pairs
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/figure skating pairs/1.jpg
#       → Predicted as: figure skating women
#
# Class: frisbee
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/frisbee/4.jpg
#       → Predicted as: figure skating women
#
# Class: gaga
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/gaga/5.jpg
#       → Predicted as: jai alai
#
# Class: horseshoe pitching
#   Misclassified samples: 3
#     Image: /kaggle/input/sports-classification/test/horseshoe pitching/2.jpg
#       → Predicted as: frisbee
#     Image: /kaggle/input/sports-classification/test/horseshoe pitching/3.jpg
#       → Predicted as: frisbee
#     Image: /kaggle/input/sports-classification/test/horseshoe pitching/5.jpg
#       → Predicted as: frisbee
#
# Class: hydroplane racing
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/hydroplane racing/2.jpg
#       → Predicted as: sailboat racing
#     Image: /kaggle/input/sports-classification/test/hydroplane racing/5.jpg
#       → Predicted as: bobsled
#
# Class: pole vault
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/pole vault/3.jpg
#       → Predicted as: uneven bars
#
# Class: roller derby
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/roller derby/4.jpg
#       → Predicted as: football
#
# Class: shot put
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/shot put/2.jpg
#       → Predicted as: javelin
#
# Class: sky surfing
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/sky surfing/1.jpg
#       → Predicted as: skydiving
#     Image: /kaggle/input/sports-classification/test/sky surfing/5.jpg
#       → Predicted as: snow boarding
#
# Class: snowmobile racing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/snowmobile racing/2.jpg
#       → Predicted as: formula 1 racing
#
# Class: swimming
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/swimming/2.jpg
#       → Predicted as: water polo
#
# Class: trapeze
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/trapeze/2.jpg
#       → Predicted as: balance beam
#
# Class: ultimate
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/ultimate/2.jpg
#       → Predicted as: tug of war
#     Image: /kaggle/input/sports-classification/test/ultimate/3.jpg
#       → Predicted as: tug of war
#
# Class: volleyball
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/volleyball/2.jpg
#       → Predicted as: javelin
#     Image: /kaggle/input/sports-classification/test/volleyball/4.jpg
#       → Predicted as: tennis

# %%
from google.colab import drive
drive.mount('/content/drive')

torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'epoch': epoch
}, "/content/drive/MyDrive/resnet2.pth")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_ds = datasets.ImageFolder(TRAIN_DIR, transform=transform)
valid_ds = datasets.ImageFolder(VALID_DIR, transform=transform)
test_ds  = datasets.ImageFolder(TEST_DIR,  transform=transform)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_ds, batch_size=32, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False)

num_classes = len(train_ds.classes)
num_classes
# Out:
# 100

# %%
model = models.densenet121(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

model.classifier = nn.Linear(
    model.classifier.in_features, num_classes
)
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.classifier.parameters(),
    lr=1e-4
)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 176MB/s]

# %%
EPOCHS = 30
patience = 3
best_val_loss = float('inf')
patience_counter = 0

best_model_state = None

for epoch in range(EPOCHS):
    train_loss, train_acc = train_epoch(model, train_loader)
    val_loss, val_acc = eval_epoch(model, valid_loader)

    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f" Train loss: {train_loss:.4f}, acc: {train_acc:.4f}")
    print(f" Validation loss: {val_loss:.4f}, acc: {val_acc:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = model.state_dict()
        print("Validation loss improved")
    else:
        patience_counter += 1
        print(f"No improvement ({patience_counter}/{patience})")

    print("-" * 40)

    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

if best_model_state is not None:
    model.load_state_dict(best_model_state)
# Out:
# 100%|██████████| 422/422 [01:13<00:00,  5.76it/s]
# Epoch 1/30
#  Train loss: 4.0871, acc: 0.1860
#  Validation loss: 3.4678, acc: 0.4400
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:12<00:00,  5.79it/s]
# Epoch 2/30
#  Train loss: 3.0987, acc: 0.5583
#  Validation loss: 2.5572, acc: 0.7260
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:12<00:00,  5.81it/s]
# Epoch 3/30
#  Train loss: 2.3930, acc: 0.7167
#  Validation loss: 1.9671, acc: 0.7980
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:12<00:00,  5.79it/s]
# Epoch 4/30
#  Train loss: 1.8966, acc: 0.7877
#  Validation loss: 1.5338, acc: 0.8400
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:14<00:00,  5.67it/s]
# Epoch 5/30
#  Train loss: 1.5576, acc: 0.8249
#  Validation loss: 1.2531, acc: 0.8680
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:17<00:00,  5.46it/s]
# Epoch 6/30
#  Train loss: 1.3118, acc: 0.8476
#  Validation loss: 1.0476, acc: 0.8740
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:14<00:00,  5.66it/s]
# Epoch 7/30
#  Train loss: 1.1321, acc: 0.8627
#  Validation loss: 0.9068, acc: 0.8940
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:15<00:00,  5.55it/s]
# Epoch 8/30
#  Train loss: 0.9970, acc: 0.8728
#  Validation loss: 0.7978, acc: 0.8820
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [01:13<00:00,  5
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
cm = confusion_matrix(all_labels, all_preds)
class_names = train_ds.classes

for i, class_name in enumerate(class_names):
    total = cm[i].sum()
    correct = cm[i, i]

    print(f"\nClass: {class_name}")
    print(f"  Total samples : {total}")
    print(f"  Correct hits  : {correct}")

    errors = cm[i].copy()
    errors[i] = 0

    if errors.sum() == 0:
        print("  Incorrect: 0")
        continue

    print("  Misclassified as:")
    for j, count in enumerate(errors):
        if count > 0:
            print(f"    → {class_names[j]} : {count}")
# Out:
# Class: air hockey
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ampute football
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: archery
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: arm wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: axe throwing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: balance beam
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: barell racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: baseball
#   Total samples : 5
#   Correct hits  : 2
#   Misclassified as:
#     → cricket : 2
#     → football : 1
#
# Class: basketball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: baton twirling
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → javelin : 1
#
# Class: bike polo
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → wheelchair racing : 1
#
# Class: billiards
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bmx
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bobsled
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bowling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: boxing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bull riding
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bungee jumping
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → trapeze : 1
#
# Class: canoe slamon
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: cheerleading
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → football : 1
#
# Class: chuckwagon racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: cricket
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: croquet
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: curling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: disc golf
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: fencing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: field hockey
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → ultimate : 1
#
# Class: figure skating men
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: figure skating pairs
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → figure skating women : 2
#
# Class: figure skating women
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: fly fishing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: football
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: formula 1 racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: frisbee
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → shot put : 1
#
# Class: gaga
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → uneven bars : 1
#
# Class: giant slalom
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: golf
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hammer throw
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hang gliding
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: harness racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: high jump
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hockey
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horse jumping
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → jousting : 1
#
# Class: horse racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horseshoe pitching
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hurdles
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hydroplane racing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → sailboat racing : 1
#
# Class: ice climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ice yachting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: jai alai
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: javelin
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: jousting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: judo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: lacrosse
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: log rolling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: luge
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: motorcycle racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: mushing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: nascar racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: olympic wrestling
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → tug of war : 1
#
# Class: parallel bar
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → rings : 1
#
# Class: pole climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pole dancing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pole vault
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → parallel bar : 1
#
# Class: polo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pommel horse
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rings
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rock climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: roller derby
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rollerblade racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rowing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rugby
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sailboat racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: shot put
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → javelin : 1
#
# Class: shuffleboard
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sidecar racing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → motorcycle racing : 1
#
# Class: ski jumping
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sky surfing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: skydiving
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: snow boarding
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → giant slalom : 1
#
# Class: snowmobile racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: speed skating
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: steer wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sumo wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: surfing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: swimming
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → water polo : 1
#
# Class: table tennis
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: tennis
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: track bicycle
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: trapeze
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → luge : 1
#
# Class: tug of war
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ultimate
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: uneven bars
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → balance beam : 1
#
# Class: volleyball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: water cycling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: water polo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: weightlifting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wheelchair basketball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wheelchair racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wingsuit flying
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0

# %%
misclassified = defaultdict(list)

for idx, (true_label, pred_label) in enumerate(zip(all_labels, all_preds)):
    if true_label != pred_label:
        img_path, _ = test_ds.samples[idx]

        true_name = test_ds.classes[true_label]
        pred_name = test_ds.classes[pred_label]

        misclassified[true_name].append({
            "image": img_path,
            "predicted": pred_name
        })

for true_class, items in misclassified.items():
    print(f"\nClass: {true_class}")
    print(f"  Misclassified samples: {len(items)}")

    for item in items:
        print(f"    Image: {item['image']}")
        print(f"      → Predicted as: {item['predicted']}")
# Out:
# Class: baseball
#   Misclassified samples: 3
#     Image: /kaggle/input/sports-classification/test/baseball/1.jpg
#       → Predicted as: cricket
#     Image: /kaggle/input/sports-classification/test/baseball/2.jpg
#       → Predicted as: cricket
#     Image: /kaggle/input/sports-classification/test/baseball/3.jpg
#       → Predicted as: football
#
# Class: baton twirling
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/baton twirling/5.jpg
#       → Predicted as: javelin
#
# Class: bike polo
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/bike polo/1.jpg
#       → Predicted as: wheelchair racing
#
# Class: bungee jumping
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/bungee jumping/4.jpg
#       → Predicted as: trapeze
#
# Class: cheerleading
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/cheerleading/2.jpg
#       → Predicted as: football
#
# Class: field hockey
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/field hockey/5.jpg
#       → Predicted as: ultimate
#
# Class: figure skating pairs
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/figure skating pairs/1.jpg
#       → Predicted as: figure skating women
#     Image: /kaggle/input/sports-classification/test/figure skating pairs/5.jpg
#       → Predicted as: figure skating women
#
# Class: frisbee
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/frisbee/4.jpg
#       → Predicted as: shot put
#
# Class: gaga
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/gaga/5.jpg
#       → Predicted as: uneven bars
#
# Class: horse jumping
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/horse jumping/4.jpg
#       → Predicted as: jousting
#
# Class: hydroplane racing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/hydroplane racing/2.jpg
#       → Predicted as: sailboat racing
#
# Class: olympic wrestling
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/olympic wrestling/2.jpg
#       → Predicted as: tug of war
#
# Class: parallel bar
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/parallel bar/4.jpg
#       → Predicted as: rings
#
# Class: pole vault
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/pole vault/3.jpg
#       → Predicted as: parallel bar
#
# Class: shot put
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/shot put/2.jpg
#       → Predicted as: javelin
#
# Class: sidecar racing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/sidecar racing/3.jpg
#       → Predicted as: motorcycle racing
#
# Class: snow boarding
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/snow boarding/4.jpg
#       → Predicted as: giant slalom
#
# Class: swimming
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/swimming/2.jpg
#       → Predicted as: water polo
#
# Class: trapeze
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/trapeze/2.jpg
#       → Predicted as: luge
#
# Class: uneven bars
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/uneven bars/3.jpg
#       → Predicted as: balance beam

# %%
from google.colab import drive
drive.mount('/content/drive')

torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'epoch': epoch
}, "/content/drive/MyDrive/densenet.pth")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = models.efficientnet_b0(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

model.classifier[1] = nn.Linear(
    model.classifier[1].in_features, num_classes
)
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.classifier[1].parameters(),
    lr=1e-4
)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 160MB/s]

# %%
EPOCHS = 30
patience = 3
best_val_loss = float('inf')
patience_counter = 0

best_model_state = None

for epoch in range(EPOCHS):
    train_loss, train_acc = train_epoch(model, train_loader)
    val_loss, val_acc = eval_epoch(model, valid_loader)

    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f" Train loss: {train_loss:.4f}, acc: {train_acc:.4f}")
    print(f" Validation loss: {val_loss:.4f}, acc: {val_acc:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = model.state_dict()
        print("Validation loss improved")
    else:
        patience_counter += 1
        print(f"No improvement ({patience_counter}/{patience})")

    print("-" * 40)

    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

if best_model_state is not None:
    model.load_state_dict(best_model_state)
# Out:
# 100%|██████████| 422/422 [00:48<00:00,  8.76it/s]
# Epoch 1/30
#  Train loss: 4.1441, acc: 0.2211
#  Validation loss: 3.6145, acc: 0.5580
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:45<00:00,  9.28it/s]
# Epoch 2/30
#  Train loss: 3.3334, acc: 0.5683
#  Validation loss: 2.8934, acc: 0.6820
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:45<00:00,  9.21it/s]
# Epoch 3/30
#  Train loss: 2.7140, acc: 0.6765
#  Validation loss: 2.3065, acc: 0.7460
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:45<00:00,  9.22it/s]
# Epoch 4/30
#  Train loss: 2.2477, acc: 0.7297
#  Validation loss: 1.8957, acc: 0.7800
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:45<00:00,  9.23it/s]
# Epoch 5/30
#  Train loss: 1.9133, acc: 0.7556
#  Validation loss: 1.6096, acc: 0.8020
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:46<00:00,  9
# ----------------------------------------
# 100%|██████████| 422/422 [00:45<00:00,  9.25it/s]
# Epoch 29/30
#  Train loss: 0.5030, acc: 0.8999
#  Validation loss: 0.4751, acc: 0.8840
# Validation loss improved
# ----------------------------------------
# 100%|██████████| 422/422 [00:45<00:00,  9.19it/s]
# Epoch 30/30
#  Train loss: 0.4877, acc: 0.8999
#  Validation loss: 0.4576, acc: 0.8900
# Validation loss improved
# ----------------------------------------

# %%
test_loss, test_acc = eval_epoch(model, test_loader)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Test accuracy: 0.8940

# %%
all_preds = []
all_labels = []

model.eval()
with torch.no_grad():
    for x, y in test_loader:
        x, y = x.to(device), y.to(device)
        out = model(x)
        _, preds = torch.max(out, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y.cpu().numpy())

# %%
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(12,10))
sns.heatmap(
    cm,
    xticklabels=train_ds.classes,
    yticklabels=train_ds.classes,
    cmap="Blues",
    fmt="d"
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
cm = confusion_matrix(all_labels, all_preds)
class_names = train_ds.classes

for i, class_name in enumerate(class_names):
    total = cm[i].sum()
    correct = cm[i, i]

    print(f"\nClass: {class_name}")
    print(f"  Total samples : {total}")
    print(f"  Correct hits  : {correct}")

    errors = cm[i].copy()
    errors[i] = 0

    if errors.sum() == 0:
        print("  Incorrect: 0")
        continue

    print("  Misclassified as:")
    for j, count in enumerate(errors):
        if count > 0:
            print(f"    → {class_names[j]} : {count}")
# Out:
# Class: air hockey
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ampute football
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: archery
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: arm wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: axe throwing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → horseshoe pitching : 1
#
# Class: balance beam
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: barell racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: baseball
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → croquet : 1
#
# Class: basketball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: baton twirling
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → tennis : 1
#
# Class: bike polo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: billiards
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bmx
#   Total samples : 5
#   Correct hits  : 2
#   Misclassified as:
#     → bike polo : 1
#     → skydiving : 1
#     → tennis : 1
#
# Class: bobsled
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → hockey : 1
#
# Class: bowling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: boxing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bull riding
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: bungee jumping
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → trapeze : 1
#
# Class: canoe slamon
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: cheerleading
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → basketball : 1
#
# Class: chuckwagon racing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → harness racing : 1
#
# Class: cricket
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: croquet
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: curling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: disc golf
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → croquet : 1
#
# Class: fencing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → judo : 1
#
# Class: field hockey
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → lacrosse : 1
#
# Class: figure skating men
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → figure skating women : 1
#
# Class: figure skating pairs
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: figure skating women
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → figure skating pairs : 1
#
# Class: fly fishing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: football
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: formula 1 racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: frisbee
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → boxing : 1
#
# Class: gaga
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → air hockey : 1
#
# Class: giant slalom
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: golf
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hammer throw
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hang gliding
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: harness racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: high jump
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hockey
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → parallel bar : 1
#
# Class: horse jumping
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horse racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: horseshoe pitching
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → frisbee : 2
#
# Class: hurdles
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: hydroplane racing
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → bobsled : 1
#     → sailboat racing : 1
#
# Class: ice climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ice yachting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: jai alai
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: javelin
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → high jump : 1
#     → uneven bars : 1
#
# Class: jousting
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → harness racing : 1
#
# Class: judo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: lacrosse
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → football : 2
#
# Class: log rolling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: luge
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: motorcycle racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: mushing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: nascar racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: olympic wrestling
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → sidecar racing : 1
#
# Class: parallel bar
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → judo : 1
#
# Class: pole climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pole dancing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → pole vault : 1
#
# Class: pole vault
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → high jump : 1
#
# Class: polo
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: pommel horse
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rings
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rock climbing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: roller derby
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rollerblade racing
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → roller derby : 1
#     → track bicycle : 1
#
# Class: rowing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: rugby
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sailboat racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: shot put
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → javelin : 1
#
# Class: shuffleboard
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sidecar racing
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → motorcycle racing : 2
#
# Class: ski jumping
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sky surfing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → snow boarding : 1
#
# Class: skydiving
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: snow boarding
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → rock climbing : 1
#
# Class: snowmobile racing
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → bmx : 1
#
# Class: speed skating
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: steer wrestling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: sumo wrestling
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → judo : 1
#
# Class: surfing
#   Total samples : 5
#   Correct hits  : 2
#   Misclassified as:
#     → canoe slamon : 2
#     → rowing : 1
#
# Class: swimming
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → water polo : 1
#
# Class: table tennis
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → weightlifting : 1
#
# Class: tennis
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → hurdles : 1
#     → table tennis : 1
#
# Class: track bicycle
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: trapeze
#   Total samples : 5
#   Correct hits  : 2
#   Misclassified as:
#     → pole vault : 1
#     → rings : 1
#     → sumo wrestling : 1
#
# Class: tug of war
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: ultimate
#   Total samples : 5
#   Correct hits  : 3
#   Misclassified as:
#     → lacrosse : 1
#     → polo : 1
#
# Class: uneven bars
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: volleyball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: water cycling
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: water polo
#   Total samples : 5
#   Correct hits  : 4
#   Misclassified as:
#     → swimming : 1
#
# Class: weightlifting
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wheelchair basketball
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wheelchair racing
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0
#
# Class: wingsuit flying
#   Total samples : 5
#   Correct hits  : 5
#   Incorrect: 0

# %%
misclassified = defaultdict(list)

for idx, (true_label, pred_label) in enumerate(zip(all_labels, all_preds)):
    if true_label != pred_label:
        img_path, _ = test_ds.samples[idx]

        true_name = test_ds.classes[true_label]
        pred_name = test_ds.classes[pred_label]

        misclassified[true_name].append({
            "image": img_path,
            "predicted": pred_name
        })

for true_class, items in misclassified.items():
    print(f"\nClass: {true_class}")
    print(f"  Misclassified samples: {len(items)}")

    for item in items:
        print(f"    Image: {item['image']}")
        print(f"      → Predicted as: {item['predicted']}")
# Out:
# Class: axe throwing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/axe throwing/1.jpg
#       → Predicted as: horseshoe pitching
#
# Class: baseball
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/baseball/3.jpg
#       → Predicted as: croquet
#
# Class: baton twirling
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/baton twirling/1.jpg
#       → Predicted as: tennis
#
# Class: bmx
#   Misclassified samples: 3
#     Image: /kaggle/input/sports-classification/test/bmx/2.jpg
#       → Predicted as: skydiving
#     Image: /kaggle/input/sports-classification/test/bmx/3.jpg
#       → Predicted as: bike polo
#     Image: /kaggle/input/sports-classification/test/bmx/5.jpg
#       → Predicted as: tennis
#
# Class: bobsled
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/bobsled/3.jpg
#       → Predicted as: hockey
#
# Class: bungee jumping
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/bungee jumping/4.jpg
#       → Predicted as: trapeze
#
# Class: cheerleading
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/cheerleading/5.jpg
#       → Predicted as: basketball
#
# Class: chuckwagon racing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/chuckwagon racing/3.jpg
#       → Predicted as: harness racing
#
# Class: disc golf
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/disc golf/1.jpg
#       → Predicted as: croquet
#
# Class: fencing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/fencing/3.jpg
#       → Predicted as: judo
#
# Class: field hockey
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/field hockey/5.jpg
#       → Predicted as: lacrosse
#
# Class: figure skating men
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/figure skating men/3.jpg
#       → Predicted as: figure skating women
#
# Class: figure skating women
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/figure skating women/2.jpg
#       → Predicted as: figure skating pairs
#
# Class: frisbee
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/frisbee/4.jpg
#       → Predicted as: boxing
#
# Class: gaga
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/gaga/5.jpg
#       → Predicted as: air hockey
#
# Class: hockey
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/hockey/5.jpg
#       → Predicted as: parallel bar
#
# Class: horseshoe pitching
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/horseshoe pitching/2.jpg
#       → Predicted as: frisbee
#     Image: /kaggle/input/sports-classification/test/horseshoe pitching/3.jpg
#       → Predicted as: frisbee
#
# Class: hydroplane racing
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/hydroplane racing/2.jpg
#       → Predicted as: sailboat racing
#     Image: /kaggle/input/sports-classification/test/hydroplane racing/5.jpg
#       → Predicted as: bobsled
#
# Class: javelin
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/javelin/1.jpg
#       → Predicted as: high jump
#     Image: /kaggle/input/sports-classification/test/javelin/3.jpg
#       → Predicted as: uneven bars
#
# Class: jousting
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/jousting/2.jpg
#       → Predicted as: harness racing
#
# Class: lacrosse
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/lacrosse/2.jpg
#       → Predicted as: football
#     Image: /kaggle/input/sports-classification/test/lacrosse/5.jpg
#       → Predicted as: football
#
# Class: olympic wrestling
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/olympic wrestling/4.jpg
#       → Predicted as: sidecar racing
#
# Class: parallel bar
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/parallel bar/2.jpg
#       → Predicted as: judo
#
# Class: pole dancing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/pole dancing/5.jpg
#       → Predicted as: pole vault
#
# Class: pole vault
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/pole vault/3.jpg
#       → Predicted as: high jump
#
# Class: rollerblade racing
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/rollerblade racing/2.jpg
#       → Predicted as: track bicycle
#     Image: /kaggle/input/sports-classification/test/rollerblade racing/5.jpg
#       → Predicted as: roller derby
#
# Class: shot put
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/shot put/2.jpg
#       → Predicted as: javelin
#
# Class: sidecar racing
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/sidecar racing/3.jpg
#       → Predicted as: motorcycle racing
#     Image: /kaggle/input/sports-classification/test/sidecar racing/5.jpg
#       → Predicted as: motorcycle racing
#
# Class: sky surfing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/sky surfing/5.jpg
#       → Predicted as: snow boarding
#
# Class: snow boarding
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/snow boarding/1.jpg
#       → Predicted as: rock climbing
#
# Class: snowmobile racing
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/snowmobile racing/3.jpg
#       → Predicted as: bmx
#
# Class: sumo wrestling
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/sumo wrestling/5.jpg
#       → Predicted as: judo
#
# Class: surfing
#   Misclassified samples: 3
#     Image: /kaggle/input/sports-classification/test/surfing/2.jpg
#       → Predicted as: canoe slamon
#     Image: /kaggle/input/sports-classification/test/surfing/3.jpg
#       → Predicted as: canoe slamon
#     Image: /kaggle/input/sports-classification/test/surfing/4.jpg
#       → Predicted as: rowing
#
# Class: swimming
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/swimming/2.jpg
#       → Predicted as: water polo
#
# Class: table tennis
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/table tennis/4.jpg
#       → Predicted as: weightlifting
#
# Class: tennis
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/tennis/2.jpg
#       → Predicted as: table tennis
#     Image: /kaggle/input/sports-classification/test/tennis/5.jpg
#       → Predicted as: hurdles
#
# Class: trapeze
#   Misclassified samples: 3
#     Image: /kaggle/input/sports-classification/test/trapeze/1.jpg
#       → Predicted as: rings
#     Image: /kaggle/input/sports-classification/test/trapeze/2.jpg
#       → Predicted as: sumo wrestling
#     Image: /kaggle/input/sports-classification/test/trapeze/4.jpg
#       → Predicted as: pole vault
#
# Class: ultimate
#   Misclassified samples: 2
#     Image: /kaggle/input/sports-classification/test/ultimate/2.jpg
#       → Predicted as: polo
#     Image: /kaggle/input/sports-classification/test/ultimate/5.jpg
#       → Predicted as: lacrosse
#
# Class: water polo
#   Misclassified samples: 1
#     Image: /kaggle/input/sports-classification/test/water polo/1.jpg
#       → Predicted as: swimming

# %%
from google.colab import drive
drive.mount('/content/drive')

torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'epoch': epoch
}, "/content/drive/MyDrive/efficientnet.pth")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
